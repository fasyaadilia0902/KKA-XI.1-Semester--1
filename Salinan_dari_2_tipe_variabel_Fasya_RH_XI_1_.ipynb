# %% [markdown]
# <a href="https://colab.research.google.com/github/fasyaadilia0902/KKA-XI.1-Semester--1/blob/main/Salinan_dari_2_tipe_variabel_Fasya_RH_XI_1_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Konsep Dasar tipe variabel

# %% [markdown]
# Nama : Fasya Adilia Halwah
# Kelas : XI-1
# No.Absen : 10

# %%
email_user_1 = "fasyaadilia50@gmail.com"

print (email_user_1)
# Out:
# fasyaadilia50@gmail.com

# %%
sabun_lifeboy = 15000

print (sabun_lifeboy)
# Out:
# 15000

# %%
# jika variabel ingin dikalikan maka tulis (*)
print (sabun_lifeboy*5)
# Out:
# 75000

# %% [markdown]
# Peraturan Penulisan Variabel

# %%
# penulisan variabel hanya boleh menggunakan huruf,angka,dan underscore
# Tidak boleh menggunakan spasi

nama siswa = "Fasya"
print (nama siswa)
# Out:
#   File "/tmp/ipython-input-552742892.py", line 4
#     nama siswa = "Fasya"
#          ^
# SyntaxError: invalid syntax

# %%
# yang benar
nama_siswa = "Fasya"
print (nama_siswa)
# Out:
# Fasya

# %%
# Tidak boleh diawali dengan angka
1_nama_siswa = "Fasya"
print (1_nama_siswa)
# Out:
#   File "/tmp/ipython-input-3970804857.py", line 2
#     1_nama_siswa = "Fasya"
#      ^
# SyntaxError: invalid decimal literal

# %%
#yang benar
nama_siswa_1 = "Fasya"
print (nama_siswa_1)
# Out:
# Fasya

# %%
# Penulisan Variabel itu case sensitive/sensitif capslock
nama_siswa = "Fasya"
print (Nama_siswa)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1385233374.py in <cell line: 0>()
#       1 # Penulisan Variabel itu case sensitive/sensitif capslock
#       2 nama_siswa = "Fasya"
# ----> 3 print (Nama_siswa)
#
# NameError: name 'Nama_siswa' is not defined

# %%
# yang benar (semua variabel harus sama(besar/kecilnya)
nama_siswa = "Fasya"
print (nama_siswa)
# Out:
# Fasya

# %%
# Dilarang menggunakan kata kunci di bahasa python(print,if,class,for)
prin = Fasya
print (prin)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2560483242.py in <cell line: 0>()
#       1 # Dilarang menggunakan kata kunci di bahasa python
# ----> 2 prin = Fasya
#       3 print (prin)
#
# NameError: name 'Fasya' is not defined

# %%
# harus selain bahasa python
nama = "Fasya"
print (nama)
# Out:
# Fasya

# %%
end = "Fasya"
print (end)
# Out:
# Fasya

# %%
# Harus menggunakan deskriptif,biar gampang cara membedakan variabelnya
Contoh
_ = "Fasya"
print (_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1107530631.py in <cell line: 0>()
#       1 # Harus menggunakan deskriptif,biar gampang cara membedakan variabelnya
# ----> 2 Contoh
#       3 _ = "Fasya"
#       4 print (_)
#
# NameError: name 'Contoh' is not defined

# %%
#yang benar contoh
nama_siswa_kelas_11 = "Fasya"

print (nama_siswa_kelas_11)
# Out:
# Fasya

# %%
# Tidak boleh menggunakan kata kunci python
# kalau error,harus disconnect dulu
# print = "Fasya"

#print(print)

# %% [markdown]
# # Assignment

# %% [markdown]
# ## Single Assignment

# %%
nama_siswa_2 = "Dhapne"
nama_siswa_3 = "Farel"

print (nama_siswa_2)
print (nama_siswa_3)
# Out:
# Dhapne
# Farel

# %%
susu  = "15.000"
Roti  = "12.000"
Telur = "24.000"

print (susu)
print (Roti)
print (Telur)
# Out:
# 15.000
# 12.000
# 24.000

# %% [markdown]
# ##Multiple Assignment

# %%
nama_siswa_4, nama_siswa_5 = "Sada", "Shelo"

print (nama_siswa_4)
print (nama_siswa_5)
# Out:
# Sada
# Shelo

# %%
Gula, Minyak = "14.000", "20.000"
print (Gula)
print (Minyak)
# Out:
# 14.000
# 20.000

# %% [markdown]
# ##Assign ke Banyak Variabel Sekaligus

# %%
nilai_afa = nilai_favian = 100

print (nilai_afa)
print (nilai_favian)
# Out:
# 100
# 100

# %% [markdown]
# ##perubahan nilai variabel

# %%
# untuk merubah nilai, harus memutuskan disconnect dulu
nilai_afa = 95

print (nilai_afa)
# Out:
# 95

# %% [markdown]
# #Aritmatika

# %%
print ("5000*3")
# Out:
# 5000*3

# %%
# Operand tanpa disimpan dalam variabel

print ( 5000*3)
# Out:
# 15000

# %%
# Simpan Operand kedalam variabel
 harga_kojek = 6000
 banyak_porsi = 3

print (harga_kojek*banyak_porsi)
# Out:
#   File "/tmp/ipython-input-1650644247.py", line 2
#     harga_kojek = 6000
#     ^
# IndentationError: unexpected indent

# %%
# Operand tanpa disimpan dalam variabel
harga_total_kojek = 9000
print (harga_total_kojek)
# Out:
# 9000

# %%
# Simpan nilai Operand dan hasil operasi ke dalam variabel
harga_cilok = 10000
jumlah_porsi_cilok = 5
harga_total_cilok = harga_cilok*jumlah_porsi_cilok

print (harga_total_cilok)
# Out:
# 50000

# %%
uang_yang_diterima = "100000"
harga_total_cilok = "50000"
uang_kembalian (uang_yang_diterima-jumlah_total_cilok)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-428982635.py in <cell line: 0>()
#       1 uang_yang_diterima = "100000"
#       2 harga_total_cilok = "50000"
# ----> 3 uang_kembalian (uang_yang_diterima-jumlah_total_cilok)
#
# NameError: name 'uang_kembalian' is not defined

# %%
#1 Operand tanpa disimpan dalam variabel
print (24*3)
# Out:
# 72

# %%
#2 simpan hasil operand dalam variabel
jumlah_botol_perkardus = 24
jumlah_kardus = 3
total_jumlah_botol =72
print (total_jumlah_botol)
# Out:
# 72

# %%
#3
jumlah_botol_perkardus = 24
jumlah_kardus = 3

print (jumlah_botol_perkardus*jumlah_kardus)
# Out:
# 72

# %%
#4
jumlah_botol_perkardus = 24
jumlah_kardus = 3

jumlah_botol =jumlah_botol_perkardus*jumlah_kardus

print (jumlah_botol)
# Out:
# 72

# %% [markdown]
# # Tipe Variabel

# %%
usia = 65
type (usia)
# Out:
# int

# %%
berat_telur = 2.5
type (berat_telur)
# Out:
# float

# %%
nama = "Shinta"
type (nama)
# Out:
# str

# %%
remidi = False
type (remidi)
# Out:
# bool

# %%
remidi = True
type (remidi)
# Out:
# bool

# %%
koordinat_bintang = -1.5
type (koordinat_bintang)
# Out:
# float

# %%
koordinat_titik = -8
type (koordinat_titik)
# Out:
# int

# %% [markdown]
# Input

# %%
panjang = 10
lebar = 5
luas = panjang*lebar

print (luas)
# Out:
# 50

# %%
input ()
# Out:
# 10
# '10'

# %%
panjang = input ()
# Out:
# 10

# %%
print (panjang)
# Out:
# 10

# %%
lebar = input ()
# Out:
# 5

# %%
print (lebar)
# Out:
# 5

# %%
luas = panjang*lebar

print (luas)
# Out:
# 5555555555

# %%
type(lebar)
# Out:
# str

# %%
panjang = int(panjang)

# %%
lebar = int(lebar)

# %%
type(panjang)
# Out:
# int

# %%
panjang_1 = int(input("masukkan panjang persegi : "))
# Out:
# masukkan panjang persegi : 80

# %%
panjang_2 = int(input("masukkan panjang persegi:"))
lebar_2 = int(input("masukkan lebar persegi: "))

luas_2 = panjang_2*lebar_2

print (f"panjang persegi adalah {luas_2} ^cm2")
# Out:
# masukkan panjang persegi:89
# masukkan lebar persegi: 56
# panjang persegi adalah 4984 ^cm2

# %%
jari_jari_tabung = float(input("silahkan masukkan jari jari tabung: "))
tinggi_tabung = float(input("silahkan masukkan tinggi tabung: "))
phi = 3.14

volume_tabung = phi * jari_jari_tabung**2 *tinggi_tabung

print(f"volume tabung adalah {volume_tabung} cm^3")
# Out:
# silahkan masukkan jari jari tabung: 34
# silahkan masukkan tinggi tabung: 40
# volume tabung adalah 145193.6 cm^3

# %% [markdown]
# Operator Perbandingan

# %%
print (8<5)
# Out:
# False

# %%
print (8>5)
# Out:
# True

# %%
print (9>=9)
# Out:
# True

# %%
print (8==8)
# Out:
# True

# %%
print (8==5)
# Out:
# False

# %%
print ( 1!=1)
# Out:
# False

# %%
a = 10
b = 20
c = 30

print(a<c)
# Out:
# True

# %%
print (a<30)
# Out:
# True

# %%
nilai_kka = 75
kkm_kka = 80

print (nilai_kka > kkm_kka)
# Out:
# False

# %% [markdown]
# Operator Logika

# %%
print (8>7 and 5>6 )
# Out:
# False

# %%
print (8>7 and 5<6)
# Out:
# True

# %%
print ( 8>7 or 5<6)
# Out:
# True

# %%
print (not( 8>7 or 5>6))
# Out:
# False

# %%
print (not(8>=9 or 9!=8))
# Out:
# False

# %%
iq_min = 125
tinggi_min = 165

print (125<=iq_min and 170 > tinggi_min)
# Out:
# True

# %%
iq_afa = 125
iq_min = 125

tinggi_min = 165

tinggi_afa = 170

print (iq_afa >= iq_min and tinggi_afa >= tinggi_min)
# Out:
# True

# %%
tinggi_min = 165
bb_min = 55
umur_max =25
tinggi_farel = 170
bb_farel = 55
umur_farel = 23

print (tinggi_farel >= tinggi_min and bb_farel > bb_min and umur_farel <= umur_max )
# Out:
# False
